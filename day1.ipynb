# %%
# pandas, sentence_transformers, sklearn 설치
# %pip install pandas
# %pip install sentence_transformers
# %pip install sklearn

# %%
import pandas as pd
from sentence_transformers import SentenceTransformer
from sklearn.metrics.pairwise import cosine_similarity

model = SentenceTransformer('jhgan/ko-sroberta-multitask')

sentences = ["학교가 어디인가요","저는 부산 소마고에 다니고 있습니다."]
embeddings = model.encode(sentences)

print(embeddings)
# Out:
# Downloading: 100%|██████████| 1.18k/1.18k [00:00<00:00, 287kB/s]
# Downloading: 100%|██████████| 190/190 [00:00<00:00, 40.7kB/s]
# Downloading: 100%|██████████| 4.86k/4.86k [00:00<00:00, 931kB/s]
# ...
# Downloading: 100%|██████████| 931/931 [00:00<00:00, 313kB/s]
# Downloading: 100%|██████████| 443M/443M [00:26<00:00, 16.4MB/s]
# Downloading: 100%|██████████| 53.0/53.0 [00:00<00:00, 17.7kB/s]
# ...
# Downloading: 100%|██████████| 156/156 [00:00<00:00, 41.8kB/s]
# Downloading: 100%|██████████| 495k/495k [00:01<00:00, 308kB/s]
# Downloading: 100%|██████████| 585/585 [00:00<00:00, 172kB/s]
# Downloading: 100%|██████████| 248k/248k [00:01<00:00, 157kB/s]
# Downloading: 100%|██████████| 229/229 [00:00<00:00, 113kB/s]
# [[ 0.07661942 -0.17640792  0.10510682 ...  0.61646074  0.5970334
#   -0.7791018 ]
#  [ 0.10453971  0.19116944 -0.9161046  ... -0.16573648  0.2077941
#   -0.3483476 ]]

# %%
import pandas as pd
df = pd.read_csv('bsm_chatbot.csv')

df.head()
# Out:
#      구분                                                 유저  \
# 0  질의응답                                 코딩테스트는 어떤 방식으로 치나요
# 1  질의응답                               기숙사 잔류 허용 여부가 궁금합니다.
# 2  질의응답  차후 대학 진학시 요령은? (3년 후 진학 계획시 본교 졸업 관련학과로 가고자 할 ...
# 3  질의응답                  개인적 사유 또는 적성이 맞지 않는 경우 전학이 가능한가요?
# 4  질의응답                                  산업체 협약 현황이 궁금합니다.
#
#                                                   챗봇
# 0  문제는 시험지로 주어질 것이고 사용할 수 있는 프로그래밍 언어로는 C언어를 사용합니...
# 1  저희 학교는 전 인원 기숙생활을 해야하며, 금요일 마다 외출하는 것을 원칙으로 합니...
# 2  3년 후 대학에 진학하는 제도가 바로 재직자 특별전형입니다. 특별한 경력이나 소질 ...
# 3  개인적 사유 또는 SW 분야에 적성에 맞지 않다고 생각된다면 입학전형에 지원하지 않...
# 4  현재 ㈜마이다스아이티, ㈜잉카인터넷, ㈜더존비즈온, ㈜파나시아 등 107개 업체와 ...

# %%
df['embedding'] = df['유저'].map(lambda x: list (model.encode (x) ) )
df.head()
# Out:
#      구분                                                 유저  \
# 0  질의응답                                 코딩테스트는 어떤 방식으로 치나요
# 1  질의응답                               기숙사 잔류 허용 여부가 궁금합니다.
# 2  질의응답  차후 대학 진학시 요령은? (3년 후 진학 계획시 본교 졸업 관련학과로 가고자 할 ...
# 3  질의응답                  개인적 사유 또는 적성이 맞지 않는 경우 전학이 가능한가요?
# 4  질의응답                                  산업체 협약 현황이 궁금합니다.
#
#                                                   챗봇  \
# 0  문제는 시험지로 주어질 것이고 사용할 수 있는 프로그래밍 언어로는 C언어를 사용합니...
# 1  저희 학교는 전 인원 기숙생활을 해야하며, 금요일 마다 외출하는 것을 원칙으로 합니...
# 2  3년 후 대학에 진학하는 제도가 바로 재직자 특별전형입니다. 특별한 경력이나 소질 ...
# 3  개인적 사유 또는 SW 분야에 적성에 맞지 않다고 생각된다면 입학전형에 지원하지 않...
# 4  현재 ㈜마이다스아이티, ㈜잉카인터넷, ㈜더존비즈온, ㈜파나시아 등 107개 업체와 ...
#
#                                            embedding
# 0  [-0.93938184, -0.24477823, 0.045364168, -0.910...
# 1  [-0.44025153, -0.41250068, -0.18855706, -0.103...
# 2  [-0.2253434, -0.27981457, 0.17489511, -0.60440...
# 3  [-0.8130931, -0.053485934, 0.10808094, -0.6506...
# ...

# %%
df.to_csv('bsm_chatbot.csv', index = False)

# %%
text = ' 소마고를 소개해주세요. '
embedding = model.encode (text)
df['distance'] = df['embedding'].map(lambda x: cosine_similarity([embedding], [x]).squeeze())
df.head()
# Out:
#      구분                                                 유저  \
# 0  질의응답                                 코딩테스트는 어떤 방식으로 치나요
# 1  질의응답                               기숙사 잔류 허용 여부가 궁금합니다.
# 2  질의응답  차후 대학 진학시 요령은? (3년 후 진학 계획시 본교 졸업 관련학과로 가고자 할 ...
# 3  질의응답                  개인적 사유 또는 적성이 맞지 않는 경우 전학이 가능한가요?
# 4  질의응답                                  산업체 협약 현황이 궁금합니다.
#
#                                                   챗봇  \
# 0  문제는 시험지로 주어질 것이고 사용할 수 있는 프로그래밍 언어로는 C언어를 사용합니...
# 1  저희 학교는 전 인원 기숙생활을 해야하며, 금요일 마다 외출하는 것을 원칙으로 합니...
# 2  3년 후 대학에 진학하는 제도가 바로 재직자 특별전형입니다. 특별한 경력이나 소질 ...
# 3  개인적 사유 또는 SW 분야에 적성에 맞지 않다고 생각된다면 입학전형에 지원하지 않...
# 4  현재 ㈜마이다스아이티, ㈜잉카인터넷, ㈜더존비즈온, ㈜파나시아 등 107개 업체와 ...
#
#                                            embedding  distance
# 0  [-0.93938184, -0.24477823, 0.045364168, -0.910...  0.043277
# 1  [-0.44025153, -0.41250068, -0.18855706, -0.103...  0.115941
# 2  [-0.2253434, -0.27981457, 0.17489511, -0.60440...  0.150927
# ...

# %%
answer = df.loc[df['distance'].idxmax()]
print(answer['구분'])
print(answer['유저'])
print(answer['챗봇'])
print(answer['distance'])
# Out:
# 일반대화
# 안녕하세요
# 안녕하세요, 부산소프트웨어 입학 안내 챗봇 아리 입니다:)
# 0.24539662897586823

# %%
# streamlit 설치 해주기 
# streamlit : 
# html,css,js를 잘 몰라도 데이터 관련 dashboard 및 다양한 기능을 프로토 타입으로 구현하고 배포까지 할 수 있는 툴
# %pip install streamlit
# %pip install streamlit_chat
# Out:
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...
# Note: you may need to restart the kernel to use updated packages.
# huggingface/tokenizers: The current process just got forked, after parallelism has already been used. Disabling parallelism to avoid deadlocks...
# To disable this warning, you can either:
# 	- Avoid using `tokenizers` before the fork if possible
# 	- Explicitly set the environment variable TOKENIZERS_PARALLELISM=(true | false)
# ...
#      ━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━━ 1.2/1.2 MB 6.8 MB/s eta 0:00:00a 0:00:01
# ...
# Note: you may need to restart the kernel to use updated packages.
